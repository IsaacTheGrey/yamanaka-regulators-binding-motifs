# %% [markdown]
# # Environment setup

# %%
pip install pyfaidx Bio matplotlib regex
# Out:
# Requirement already satisfied: pyfaidx in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (0.8.1.3)
# Requirement already satisfied: Bio in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (1.7.1)
# Requirement already satisfied: matplotlib in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: regex in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (2024.11.6)
# Requirement already satisfied: importlib-metadata in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from pyfaidx) (8.6.1)
# Requirement already satisfied: packaging in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from pyfaidx) (24.2)
# Requirement already satisfied: biopython>=1.80 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (1.85)
# Requirement already satisfied: gprofiler-official in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (1.0.0)
# Requirement already satisfied: mygene in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (3.2.2)
# Requirement already satisfied: pandas in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (2.2.3)
# Requirement already satisfied: pooch in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (1.8.2)
# Requirement already satisfied: requests in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (2.32.3)
# Requirement already satisfied: tqdm in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from Bio) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: pillow>=8 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from importlib-metadata->pyfaidx) (3.21.0)
# Requirement already satisfied: biothings-client>=0.2.6 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from mygene->Bio) (0.4.1)
# Requirement already satisfied: pytz>=2020.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from pooch->Bio) (4.3.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from requests->Bio) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from requests->Bio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from requests->Bio) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from requests->Bio) (2025.1.31)
# Requirement already satisfied: httpx>=0.22.0 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from biothings-client>=0.2.6->mygene->Bio) (0.28.1)
# Requirement already satisfied: anyio in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /home/federico/.local/share/mamba/envs/jupyter/lib/python3.13/site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from pyfaidx import Fasta
from Bio.Seq import Seq
import regex as re

# === SETTINGS ===
genome = Fasta("../references/genome.fold.FINAL.fasta.noDuplicates_noMito.fasta")

# Motifs and allowed mismatches
motifs = [
    ("CACGTG", 0),  # strict match
    ("GTTAAGCAAATTAAATTTGATTCT", 6)  # allow up to 3 substitutions
]

motif_regex = [
    re.compile(f"({motif}){{s<={n},i<=0,d<=0}}")
    for motif, n in motifs
]

# Target loci: (gene_name, chromosome, center_position, window)
targets = [
    ("test", "HiC_scaffold_10", 123456, 10000),
    ("SoxB1", "HiC_scaffold_9", 39576426, 100000),
]

os.makedirs("motif_plots", exist_ok=True)

summary = []

for gene, chrom, center, window in targets:
    region_start = center - window
    region_end = center + window

    print(f"\n🔍 Checking {gene} ({chrom}:{region_start}-{region_end})")

    try:
        seq_region = genome[chrom][region_start:region_end].seq.upper()
    except KeyError:
        print(f"❌ Chromosome '{chrom}' not found in genome FASTA.")
        continue

    rev_comp = str(Seq(seq_region).reverse_complement())
    hits = []

    for (motif, max_mismatch), rx in zip(motifs, motif_regex):
        # Forward strand
        for match in rx.finditer(seq_region, overlapped=True):
            mismatches = match.fuzzy_counts[0]
            match_seq = match.group()
            hits.append((gene, chrom, "+", match.start() + region_start, motif, match_seq, mismatches))

        # Reverse strand
        for match in rx.finditer(rev_comp, overlapped=True):
            mismatches = match.fuzzy_counts[0]
            match_seq = str(Seq(match.group()).reverse_complement())
            hits.append((gene, chrom, "-", region_end - match.start() - 1, motif, match_seq, mismatches))

    # === Save table ===
    df = pd.DataFrame(hits, columns=["gene", "chrom", "strand", "position", "motif", "matched_seq", "mismatches"])
    tsv_file = f"motif_plots/{gene}_{chrom}_{center}_motif_hits.tsv"
    df.to_csv(tsv_file, sep="\t", index=False)

    if df.empty:
        print(f"⚠️ No motifs found for {gene}")
    else:
        print(df.to_string(index=False))

    summary.append((gene, chrom, len(df)))

    # === Plot ===
    fig, ax = plt.subplots(figsize=(10, 2))
    ax.hlines(0, region_start, region_end, color="gray", linewidth=2)
    ax.set_xlim(region_start, region_end)
    ax.set_ylim(-2, 2)
    ax.set_yticks([-1, 0, 1])
    ax.set_yticklabels(["Rev", "", "Fwd"])
    ax.set_xlabel(f"Genomic position on {chrom}")
    ax.set_title(f"{gene} ({chrom}:{region_start}-{region_end})")

    for _, _, strand, pos, motif, matched_seq, mismatches in hits:
        y = 1 if strand == "+" else -1
        label = f"{matched_seq} ({motif}, mm={mismatches})"
        ax.plot(pos, y, marker="^", color="blue" if strand == "+" else "red", markersize=8)
        ax.text(pos, y + 0.2 if strand == "+" else y - 0.4, label, ha="center", fontsize=7, rotation=45)

    plt.tight_layout()
    plt.savefig(f"motif_plots/{gene}_{chrom}_{center}.png")
    plt.close()

# === Summary Report ===
print("\n📊 Motif Hit Summary:")
for gene, chrom, count in summary:
    print(f" - {gene} ({chrom}): {count} hits")

print("\n✅ Done. All plots and tables saved to motif_plots/")
# Out:
# 🔍 Checking test (HiC_scaffold_10:113456-133456)
# gene           chrom strand  position  motif matched_seq  mismatches
# test HiC_scaffold_10      +    126136 CACGTG      CACGTG           0
# test HiC_scaffold_10      +    131659 CACGTG      CACGTG           0
# test HiC_scaffold_10      -    131664 CACGTG      CACGTG           0
# test HiC_scaffold_10      -    126141 CACGTG      CACGTG           0
#
# 🔍 Checking SoxB1 (HiC_scaffold_9:39476426-39676426)
#  gene          chrom strand  position                    motif              matched_seq  mismatches
# SoxB1 HiC_scaffold_9      +  39495427                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39536210                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39539632                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39564481                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39564635                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39570108                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39600051                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39622526                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39622585                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39640078                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39645118                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39655163                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39655938                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39657506                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39658498                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39658560                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39672391                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39674866                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39674871                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39672396                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39658565                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39658503                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39657511                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39655943                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39655168                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39645123                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39640083                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39622590                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39622531                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39600056                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39570113                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39564640                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39564486                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39539637                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39536215                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      -  39495432                   CACGTG                   CACGTG           0
# SoxB1 HiC_scaffold_9      +  39533845 GTTAAGCAAATTAAATTTGATTCT GTTGAGATATTGAAATTTGATTTT           6
# SoxB1 HiC_scaffold_9      -  39603046 GTTAAGCAAATTAAATTTGATTCT AGAAGCAAATTTCATTTCTTGTAC           6
#
# 📊 Motif Hit Summary:
#  - test (HiC_scaffold_10): 4 hits
#  - SoxB1 (HiC_scaffold_9): 38 hits
#
# ✅ Done. All plots and tables saved to motif_plots/
# /tmp/ipykernel_562587/1923757969.py:88: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
